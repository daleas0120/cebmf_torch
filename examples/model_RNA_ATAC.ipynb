# %% [markdown]
# # Multi-dataset fitting: Joint Modeling of RNA and ATAC Data with cEBMF
#
# This example demonstrates how to use the `cebmf_torch` package to jointly analyze RNA and ATAC sequencing data using the Covariate Empirical Bayes Matrix Factorization (cEBMF) model.
# This example highlights how, although you can fit two datasets (ATAC and RNA) separately with CEBMF, you can also do this jointly by using the updated estimates of one as the covariate data for the other
#
# **Aim:**
# - Show how to load, prepare, and analyze multi-omic data (RNA and ATAC) with cEBMF.
# - Make the workflow accessible to users who may not have a genetics background.
#
# **What you will learn:**
# - The basics of the cEBMF model and its application to genomics data.
# - How to fit the model and interpret its outputs.
# - How to visualize and understand the results, even if you are new to matrix factorization or genomics.
# - How to run two cEBMF models in parallel by using the posterior means of one as the covariate information of the other
#
# By the end, you will be able to apply cEBMF to your own data and understand the main outputs.

# %%
import os
import sys
from contextlib import contextmanager

import matplotlib.pyplot as plt
import seaborn as sns
import torch
from matplotlib.ticker import MaxNLocator
from tqdm import tqdm

from cebmf_torch import cEBMF

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
# Hyperparameters
N = 2000 # Number of observations
P = 1000 # Length of data vector for a single observation

# Reproducibility
torch.manual_seed(1);

# %%
class TqdmStdout:
    def __init__(self, total=None, desc=None):
        self.tqdm_bar = tqdm(total=total, desc=desc)
        self._buffer = ""
        self._output = []
    def write(self, s):
        self._buffer += s
        while '\n' in self._buffer:
            line, self._buffer = self._buffer.split('\n', 1)
            self._output.append(line)
            self.tqdm_bar.update(1)
    def flush(self):
        pass  # Needed for compatibility
    def close(self):
        self.tqdm_bar.close()
    @property
    def output(self):
        return self._output

@contextmanager
def tqdm_stdout(total=None, desc=None):
    old_stdout = sys.stdout
    t = TqdmStdout(total=total, desc=desc)
    sys.stdout = t
    try:
        yield t
    finally:
        sys.stdout = old_stdout
        t.close()

class suppress_stdout:
    def __enter__(self):
        self._original_stdout = sys.stdout
        sys.stdout = open(os.devnull, 'w')
    def __exit__(self, exc_type, exc_val, exc_tb):
        sys.stdout.close()
        sys.stdout = self._original_stdout

# %% [markdown]
# ## Data generation
#
# **About RNA and ATAC:**
# - **RNA-seq** measures gene expression, i.e., how much each gene is "turned on" in a cell or tissue. The resulting data matrix typically has genes as rows and samples/cells as columns.
# - **ATAC-seq** measures chromatin accessibility, i.e., which regions of DNA are open and potentially active. The data matrix is similar, but rows represent genomic regions (peaks) instead of genes.
#
# **What we do in this section:**
# - We generate example RNA and ATAC data matrices. This allows us to demonstrate the cEBMF workflow without needing real biological data.
# - The generated data mimics the structure and variability found in real experiments, so you can see how the model works in practice.
# - You can later replace this with your own data for real analyses.

# %% [markdown]
# ### ATAC Data
#
# In this example, we assume that the ATAC data is formed from a rank-2 decomposition.
# The two ranks correspond to spikes at $t\sim 250$ and another at $t \sim 750$.

# %%
f1 = torch.zeros(P)
f1[200:250] = 1

f2 = torch.zeros(P)
f2[700:750] = 1

plt.figure(figsize=(10, 4))
plt.plot(f1, label='Factor 1')
plt.plot(f2, label='Factor 2', ls='--')
plt.legend()
plt.title('True Factors')
plt.xlabel('Observation Index')
plt.ylabel('Factor Value');

# %% [markdown]
# Generate random, noiseless observations for ATAC

# %%
L1=   torch.randint(0, 2, (N,), dtype=torch.float32)
L2=   torch.randint(0, 2, (N,), dtype=torch.float32)
F_ATAC= torch.vstack([f1, f2 ] )
L_ATAC= torch.vstack([L1, L2 ] ).T
X_ATAC= L_ATAC @F_ATAC

plt.figure(figsize=(10, 4))
sns.heatmap(X_ATAC)
plt.title('Noiseless ATAC Data')
plt.xlabel('Feature Index')
plt.ylabel('Observation Index');

# %% [markdown]
# ### RNA Data
#
# We assume that RNA data can be formed from a rank-3 decomposition, consisting of spikes at threee particular feature indices. Note we will construct our observations from four basis factors here (which will be useful for our model for relating ATAC and RNA), although the rank is still 3.

# %%
f1r= torch.zeros(P)
f1r[200:250]=1
f1r[500:550]=1
f1r[700:750]=1

f2r= torch.zeros(P)
f2r[500:550]=1
f2r[700:750]=1

f3r= torch.zeros(P)
f3r[200:250]=1
f3r[700:750]=1

f4r= torch.zeros(P)
f4r[200:250]=1
f4r[500:550]=1

fig, axs = plt.subplots(1, 4, figsize=(20, 4), sharey=True)
axs[0].plot(f1r, label='Factor 1')
axs[1].plot(f2r, label='Factor 2', ls='--')
axs[2].plot(f3r, label='Factor 3', ls='-.')
axs[3].plot(f4r, label='Factor 4', ls=':')
for i, ax in enumerate(axs):
    ax.set_title(f'Factor {i+1}')
    ax.set_xlabel('Observation Index')
axs[0].set_ylabel('Factor Value')
fig.suptitle('True Factors')

fig.tight_layout()

# %% [markdown]
# We assume that the noiseless RNA data is determined solely by the ATAC data for the same observation.

# %%
L_RNA = torch.zeros(N, 4)

L_RNA = torch.zeros(N, 4, dtype=torch.float32, device=L_ATAC.device)

mask01 = (L_ATAC[:,0] == 0) & (L_ATAC[:,1] == 1)  # -> col 0
mask10 = (L_ATAC[:,0] == 1) & (L_ATAC[:,1] == 0)  # -> col 1
mask11 = (L_ATAC[:,0] == 1) & (L_ATAC[:,1] == 1)  # -> col 2
mask00 = (L_ATAC[:,0] == 0) & (L_ATAC[:,1] == 0)  # -> col 3

L_RNA[mask01, 0] = 1
L_RNA[mask10, 1] = 1
L_RNA[mask11, 2] = 1
L_RNA[mask00, 3] = 1

f_RNA = torch.vstack([f1r,f2r,f3r,f4r])

X_RNA= L_RNA @ f_RNA
plt.figure(figsize=(10, 4))
plt.title('Noiseless RNA Data')
sns.heatmap(X_RNA)
plt.xlabel('Feature Index')
plt.ylabel('Observation Index');

# %% [markdown]
# ### Noise data

# %%
X_obs_RNA = X_RNA + 0.5*torch.randn(N, P)
X_obs_ATAC = X_ATAC + 0.5*torch.randn(N, P)

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
sns.heatmap(X_obs_ATAC)
plt.title('Observed ATAC Data')
plt.xlabel('Feature Index')
plt.ylabel('Observation Index')
plt.subplot(1, 2, 2)
sns.heatmap(X_obs_RNA)
plt.title('Observed RNA Data')
plt.xlabel('Feature Index')
plt.ylabel('Observation Index')
plt.tight_layout();

# %% [markdown]
# ## Perform EMBF separately for RNA and ATAC
#
# In this section, we demonstrate the simplest scenario: we assume that the RNA and ATAC datasets are uncoupled, meaning there is no explicit sharing of information between them during modeling.
#
# We fit the cEBMF model independently to each dataset. This allows us to see how the model performs when each data type is analyzed in isolation, without leveraging any potential relationships between them.
#
# This serves as a baseline for comparison with the joint/covariate modeling approach shown later in the example.

# %%
niter = 30
K = 6

mycebmf0R = cEBMF(
    data=X_obs_RNA,
    X_f = torch.arange(X_obs_RNA.shape[1]).unsqueeze(0).repeat(N, 1).T,
    prior_F='cgb',
    prior_F_kwargs={'penalty':1.5},
    prior_L='norm',
    prior_L_kwargs={'penalty':1.5},
    K=K,
    device=device
)
mycebmf0R.initialise_factors()
with tqdm_stdout(desc="Fitting RNA", total=niter*5*K) as t:
    res_RNA = mycebmf0R.fit(niter)

mycebmf0A = cEBMF(
    data=X_obs_ATAC,
    X_f = torch.arange(X_obs_ATAC.shape[1]).unsqueeze(0).repeat(N, 1).T,
    prior_F='cgb',
    prior_F_kwargs={'penalty':1.5},
    prior_L='norm',
    prior_L_kwargs={'penalty':1.5},
    K=K,
    device=device
)
mycebmf0A.initialise_factors()
with tqdm_stdout(desc="Fitting ATAC", total=niter*5*K) as t:
    res_ATAC = mycebmf0A.fit(niter)
# Out:
# Fitting RNA: 100%|██████████| 900/900 [06:07<00:00,  2.45it/s]
# Fitting ATAC: 100%|██████████| 900/900 [06:59<00:00,  2.14it/s]

# %% [markdown]
# Here we check the loss as a function of iteration to see if our model has converged

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))
axs[0].plot(res_ATAC.history_obj)
axs[0].set_title('ATAC Convergence')
axs[1].plot(res_RNA.history_obj)
axs[1].set_title('RNA Convergence')
for ax in axs:
    ax.set_xlabel('Iteration')
    ax.set_ylabel('Objective Value')
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
fig.tight_layout();

# %% [markdown]
# Visualize the posterior mean loadings for ATAC and RNA

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
sns.heatmap(res_ATAC.L.cpu())
plt.title('Posterior mean ATAC L')
plt.xlabel('Factor index')
plt.ylabel('Observation Index')
plt.subplot(1, 2, 2)
sns.heatmap(res_RNA.L.cpu())
plt.title('Posterior mean RNA L')
plt.xlabel('Factor index')
plt.ylabel('Observation Index')
plt.tight_layout();

# %% [markdown]
# Visualize the posterior mean factors for ATAC and RNA

# %%
fig, axs = plt.subplots(2, 4, figsize=(15, 6), sharex=True, sharey='row')

print(res_ATAC.F.shape, res_RNA.F.shape)

for i in range(axs.shape[1]):

    axs[0,i].plot(res_ATAC.F[:,i].cpu(), label=f'Factor {i+1}')
    axs[1,i].plot(res_RNA.F[:,i].cpu(), label=f'Factor {i+1}', color='orange')
    axs[0,i].set_title(f'ATAC Factor {i+1}')
    axs[1,i].set_title(f'RNA Factor {i+1}')

    axs[1,i].set_xlabel('Feature Index')

for ax in axs[:,0]:
    ax.set_ylabel('Factor Value')

fig.tight_layout();
# Out:
# torch.Size([1000, 6]) torch.Size([1000, 6])

# %% [markdown]
# ## Covariate EMBF Model for RNA and ATAC
#
# We now try to use the covariate information of RNA to inform our ATAC prior,
# and the information of ATAC to inform our RNA prior.
#
# Instead of starting from scratch, we use our inferred $L$ and $F$ from the EMBF
# analysis above to determine the initial $L$ and $F$ for this analysis (overriding
# the default SVD values for this).
#
# At each step in the optimisation, we take the current posterior mean $L$ from
# ATAC as our covariate for $L$ of RNA. For the covariate of $F$, we use feature index.
# Once we have a new estimate of $L$ for RNA, we then feed this into our ATAC inference
# to be used as the covariate of $L$ for ATAC. We continue this for many interations
# and hope for convergence.

# %%
# Feature index as the covariate for F
y_rna = torch.arange(1, X_obs_RNA.shape[1] + 1, dtype=torch.float32)
y_atac = torch.arange(1, X_obs_ATAC.shape[1] + 1, dtype=torch.float32)

# %%
mycebmfR = cEBMF(
    data=X_obs_RNA,
    prior_F="cgb",
    prior_F_kwargs={'penalty':1.5},
    X_f=y_rna,
    prior_L='cgb',
    X_l = mycebmf0A.L,
    prior_L_kwargs={'penalty':1.5},
    K=K,
    allow_backfitting=False,
    device=device
)
mycebmfR.initialise_factors(L=mycebmf0R.L.clone(), F=mycebmf0R.F.clone())

mycebmfA = cEBMF(
    data=X_obs_ATAC,
    prior_F="cgb",
    prior_F_kwargs={'penalty':1.5},
    X_f=y_atac,
    prior_L='cgb',
    X_l = mycebmf0R.L,
    prior_L_kwargs={'penalty':1.5},
    K=K,
    allow_backfitting=False,
    device=device
)
mycebmfA.initialise_factors(L=mycebmf0A.L.clone(), F=mycebmf0A.F.clone())

# %%
nupdate = 30

RNA_loss = []
ATAC_loss = []

# Compute initial losses
mycebmfR._cal_obj()
mycebmfA._cal_obj()

for i in range(nupdate):
    print(f'Update {i+1}/{nupdate}', flush=True)

    mycebmfR.X_l= mycebmfA.L
    with suppress_stdout():
        mycebmfR.iter_once()
    if len(RNA_loss) == 0:
        RNA_loss_init = mycebmfR.obj[-1]
    RNA_loss.append(mycebmfR.obj[-1] - RNA_loss_init)
    print(f'\tChange in RNA loss since start: {RNA_loss[-1]:.2f}', flush=True)

    mycebmfA.X_l= mycebmfR.L
    with suppress_stdout():
        mycebmfA.iter_once()
    if len(ATAC_loss) == 0:
        ATAC_loss_init = mycebmfA.obj[-1]
    ATAC_loss.append(mycebmfA.obj[-1] - ATAC_loss_init)
    print(f'\tChange in ATAC loss since start: {ATAC_loss[-1]:.2f}', flush=True)
# Out:
# Update 1/30
# 	Change in RNA loss since start: 0.00
# 	Change in ATAC loss since start: 0.00
# Update 2/30
# 	Change in RNA loss since start: -33211.38
# 	Change in ATAC loss since start: -47958.12
# Update 3/30
# 	Change in RNA loss since start: -37121.50
# 	Change in ATAC loss since start: -49559.75
# Update 4/30
# 	Change in RNA loss since start: -46850.75
# 	Change in ATAC loss since start: -51626.38
# Update 5/30
# 	Change in RNA loss since start: -58552.12
# 	Change in ATAC loss since start: -65401.38
# Update 6/30
# 	Change in RNA loss since start: -59223.88
# 	Change in ATAC loss since start: -66505.88
# Update 7/30
# 	Change in RNA loss since start: -58684.62
# 	Change in ATAC loss since start: -65684.25
# Update 8/30
# 	Change in RNA loss since start: -58852.50
# 	Change in ATAC loss since start: -69559.50
# Update 9/30
# 	Change in RNA loss since start: -61635.50
# 	Change in ATAC loss since start: -73095.25
# Update 10/30
# 	Change in RNA loss since start: -59991.12
# 	Change in ATAC loss since start: -70894.00
# Update 11/30
# 	Change in RNA loss since start: -58852.88
# 	Change in ATAC loss since start: -70680.62
# Update 12/30
# 	Change in RNA loss since start: -61474.50
# 	Change in ATAC loss since start: -70203.75
# Update 13/30
# 	Change in RNA loss since start: -59278.00
# 	Change in ATAC loss since start: -78274.00
# Update 14/30
# 	Change in RNA loss since start: -55412.75
# 	Change in ATAC loss since start: -69416.75
# Update 15/30
# 	Change in RNA loss since start: -62260.50
# 	Change in ATAC loss since start: -67810.25
# Update 16/30
# 	Change in RNA loss since start: -62937.25
# 	Change in ATAC loss since start: -65814.00
# Update 17/30
# 	Change in RNA loss since start: -56038.38
# 	Change in ATAC loss since start: -58135.62
# Update 18/30
# 	Change in RNA loss since start: -55470.88
# 	Change in ATAC loss since start: -70109.50
# Update 19/30
# 	Change in RNA loss since start: -63875.12
# 	Change in ATAC loss since start: -65402.25
# Update 20/30
# 	Change in RNA loss since start: -63438.50
# 	Change in ATAC loss since start: -68579.88
# Update 21/30
# 	Change in RNA loss since start: -64700.62
# 	Change in ATAC loss since start: -63722.62
# Update 22/30
# 	Change in RNA loss since start: -64633.00
# 	Change in ATAC loss since start: -74547.50
# Update 23/30
# 	Change in RNA loss since start: -61131.62
# 	Change in ATAC loss since start: -67182.88
# Update 24/30
# 	Change in RNA loss since start: -60829.12
# 	Change in ATAC loss since start: -72869.62
# Update 25/30
# 	Change in RNA loss since start: -61520.88
# 	Change in ATAC loss since start: -76204.62
# Update 26/30
# 	Change in RNA loss since start: -61273.25
# 	Change in ATAC loss since start: -66934.75
# Update 27/30
# 	Change in RNA loss since start: -58717.25
# 	Change in ATAC loss since start: -61052.88
# Update 28/30
# 	Change in RNA loss since start: -59401.88
# 	Change in ATAC loss since start: -72321.38
# Update 29/30
# 	Change in RNA loss since start: -62696.75
# 	Change in ATAC loss since start: -72193.75
# Update 30/30
# 	Change in RNA loss since start: -63185.62
# 	Change in ATAC loss since start: -71433.75

# %% [markdown]
# Again, we must check that our model has converged

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))
axs[0].plot(ATAC_loss)
axs[0].set_title('ATAC Convergence')
axs[1].plot(RNA_loss)
axs[1].set_title('RNA Convergence')
for ax in axs:
    ax.set_xlabel('Iteration')
    ax.set_ylabel('Change in Objective Value')
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
fig.tight_layout();

# %% [markdown]
# Visualize the new posterior means for the loadings

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
sns.heatmap(mycebmfA.L.cpu())
plt.title('Posterior mean ATAC L')
plt.xlabel('Factor index')
plt.ylabel('Observation Index')
plt.subplot(1, 2, 2)
sns.heatmap(mycebmfR.L.cpu())
plt.title('Posterior mean RNA L')
plt.xlabel('Factor index')
plt.ylabel('Observation Index')
plt.tight_layout();

# %% [markdown]
# And the new posterior means for the factors

# %%
fig, axs = plt.subplots(2, 5, figsize=(15, 6), sharex=True, sharey='row')

for i in range(axs.shape[1]):

    axs[0,i].plot(mycebmfA.F[:,i].cpu(), label=f'Factor {i+1}')
    axs[1,i].plot(mycebmfR.F[:,i].cpu(), label=f'Factor {i+1}', color='orange')
    axs[0,i].set_title(f'ATAC Factor {i+1}')
    axs[1,i].set_title(f'RNA Factor {i+1}')

    axs[1,i].set_xlabel('Feature Index')

for ax in axs[:,0]:
    ax.set_ylabel('Factor Value')

fig.tight_layout();

# %% [markdown]
# We see that there is little improvement in the factors, but then we didn't change the priors for these so perhaps that is unsurprising!
#
# However, let us now compare the difference between our inferred (posterior mean) values of $X$ and the truth, by plotting the cumulative
# density function of the residuals. We see that doing an EBMF approach independently for RNA and ATAC gives much better results than simply
# using the maximum likelihood values. However, the results are even better if we use the joint information between RNA and ATAC,
# as seen by a shift to the left of the CDF curves.

# %%
X0_R = mycebmf0R.L @ mycebmf0R.F.T
X1_R = mycebmfR.L @ mycebmfR.F.T
X0_A = mycebmf0A.L @ mycebmf0A.F.T
X1_A = mycebmfA.L @ mycebmfA.F.T

fig, axs = plt.subplots(1, 2, figsize=(9, 3), sharey=True)
diff0_R = torch.abs(X_RNA - X0_R)
diff1_R = torch.abs(X_RNA - X1_R)
diff0_A = torch.abs(X_ATAC - X0_A)
diff1_A = torch.abs(X_ATAC - X1_A)
diff_ML_R = torch.abs(X_RNA - X_obs_RNA)
diff_ML_A = torch.abs(X_ATAC - X_obs_ATAC)

bins = torch.logspace(diff0_R[diff0_R > 0].min().log10().item(), diff_ML_R.max().log10().item(), 30)
axs[0].hist(diff_ML_R.flatten(), bins=bins, alpha=0.5, label='Maximum Likelihood', histtype='step',
            lw=3, log=True, cumulative=True, density=True)
axs[0].hist(diff0_R.flatten(), bins=bins, alpha=0.5, label='Independent Fit', histtype='step',
            lw=3, log=True, cumulative=True, density=True)
axs[0].hist(diff1_R.flatten(), bins=bins, alpha=0.5, label='Joint Fit', histtype='step',
            lw=3, log=True, cumulative=True, density=True)
axs[0].set_xscale('log')
xmin, xmax = axs[0].get_xlim()
axs[0].set_xlim(xmin, bins[-2])

bins = torch.logspace(diff0_A[diff0_A > 0].min().log10().item(), diff_ML_A.max().log10().item(), 30)
axs[1].hist(diff_ML_A.flatten(), bins=bins, alpha=0.5, label='Maximum Likelihood', histtype='step',
            lw=3, log=True, cumulative=True, density=True)
axs[1].hist(diff0_A.flatten(), bins=bins, alpha=0.5, label='Independent Fit', histtype='step',
            lw=3, log=True, cumulative=True, density=True)
axs[1].hist(diff1_A.flatten(), bins=bins, alpha=0.5, label='Joint Fit', histtype='step',
            lw=3, log=True, cumulative=True, density=True)
axs[1].set_xscale('log')
xmin, xmax = axs[1].get_xlim()
axs[1].set_xlim(xmin, bins[-2])

for ax in axs:
    ax.set_xlabel(r'Residual on $X$')
    ax.legend(loc='lower right')
    ax.axhline(1, ls=':', color='grey')
axs[0].set_ylabel('Cumulative Probability')
axs[0].set_title('RNA')
axs[1].set_title('ATAC')
fig.align_labels()
fig.tight_layout();
